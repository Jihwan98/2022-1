# %% [markdown]
# ## 생능출판사 (가칭)"데이터과학 파이썬" 코드 12장

# %% [markdown]
# ### 12.4 CSV 데이터의 내용을 읽어 보자

# %%
# 교재의 코드
import csv     
 
f = open('weather.csv')  # CSV 파일을 열어서 f에 저장한다. 
data = csv.reader(f)             # reader() 함수를 이용하여 읽는다. 
for row in data: 
      print(row) 
f.close()
# Out:
# ['일시', '평균기온', '최대풍속', '평균풍속']
# ['2010-08-01', '28.7', '8.3', '3.4']
# ['2010-08-02', '25.2', '8.7', '3.8']
# ['2010-08-03', '22.1', '6.3', '2.9']
# ['2010-08-04', '25.3', '6.6', '4.2']
# ['2010-08-05', '27.2', '9.1', '5.6']
# ['2010-08-06', '26.8', '9.8', '8']
# ['2010-08-07', '27.5', '9.1', '5']
# ['2010-08-08', '26.6', '5.9', '4']
# ['2010-08-09', '26.9', '5.1', '3.1']
# ['2010-08-10', '25.6', '10.2', '5.5']
# ['2010-08-11', '24.6', '9.4', '4.8']
# ['2010-08-12', '23.7', '8.7', '2.6']
# ['2010-08-13', '24.3', '10.9', '4.6']
# ['2010-08-14', '25', '10.8', '4.4']
# ['2010-08-15', '24.5', '16.9', '10.3']
# ['2010-08-16', '26.2', '9.8', '3.2']
# ['2010-08-17', '23.9', '4.2', '1.6']
# ['2010-08-18', '23.4', '4.2', '2.1']
# ['2010-08-19', '24.3', '4', '1.9']
# ['2010-08-20', '25.4', '5', '3.2']
# ['2010-08-21', '27.8', '7.6', '4.2']
# ['2010-08-22', '28.3', '5.9', '2.5']
# ['2010-08-23', '28.9', '9.3', '6.2']
# ['2010-08-24', '27.5', '8.3', '3']
# ['2010-08-25', '24.7', '6.8', '1.9']
# ...

# %%
# 교재의 코드
import csv     
 
f = open('weather.csv')  # CSV 파일을 열어서 f에 저장한다. 
data = csv.reader(f)             # reader() 함수를 이용하여 읽는다. 
header = next(data)
for row in data: 
      print(row) 
f.close()
# Out:
# ['2010-08-01', '28.7', '8.3', '3.4']
# ['2010-08-02', '25.2', '8.7', '3.8']
# ['2010-08-03', '22.1', '6.3', '2.9']
# ['2010-08-04', '25.3', '6.6', '4.2']
# ['2010-08-05', '27.2', '9.1', '5.6']
# ['2010-08-06', '26.8', '9.8', '8']
# ['2010-08-07', '27.5', '9.1', '5']
# ['2010-08-08', '26.6', '5.9', '4']
# ['2010-08-09', '26.9', '5.1', '3.1']
# ['2010-08-10', '25.6', '10.2', '5.5']
# ['2010-08-11', '24.6', '9.4', '4.8']
# ['2010-08-12', '23.7', '8.7', '2.6']
# ['2010-08-13', '24.3', '10.9', '4.6']
# ['2010-08-14', '25', '10.8', '4.4']
# ['2010-08-15', '24.5', '16.9', '10.3']
# ['2010-08-16', '26.2', '9.8', '3.2']
# ['2010-08-17', '23.9', '4.2', '1.6']
# ['2010-08-18', '23.4', '4.2', '2.1']
# ['2010-08-19', '24.3', '4', '1.9']
# ['2010-08-20', '25.4', '5', '3.2']
# ['2010-08-21', '27.8', '7.6', '4.2']
# ['2010-08-22', '28.3', '5.9', '2.5']
# ['2010-08-23', '28.9', '9.3', '6.2']
# ['2010-08-24', '27.5', '8.3', '3']
# ['2010-08-25', '24.7', '6.8', '1.9']
# ...

# %%
# 코랩을 통해서 github의 정보를 읽어오기
import csv, urllib.request

url = 'https://raw.githubusercontent.com/dongupak/DataSciPy/master/data/csv/weather.csv'
response = urllib.request.urlopen(url)
lines = [l.decode('cp949') for l in response.readlines()]
cr = csv.reader(lines)

for row in cr:
    print(row)
# Out:
# ['일시', '평균기온', '최대풍속', '평균풍속']
# ['2010-08-01', '28.7', '8.3', '3.4']
# ['2010-08-02', '25.2', '8.7', '3.8']
# ['2010-08-03', '22.1', '6.3', '2.9']
# ['2010-08-04', '25.3', '6.6', '4.2']
# ['2010-08-05', '27.2', '9.1', '5.6']
# ['2010-08-06', '26.8', '9.8', '8']
# ['2010-08-07', '27.5', '9.1', '5']
# ['2010-08-08', '26.6', '5.9', '4']
# ['2010-08-09', '26.9', '5.1', '3.1']
# ['2010-08-10', '25.6', '10.2', '5.5']
# ['2010-08-11', '24.6', '9.4', '4.8']
# ['2010-08-12', '23.7', '8.7', '2.6']
# ['2010-08-13', '24.3', '10.9', '4.6']
# ['2010-08-14', '25', '10.8', '4.4']
# ['2010-08-15', '24.5', '16.9', '10.3']
# ['2010-08-16', '26.2', '9.8', '3.2']
# ['2010-08-17', '23.9', '4.2', '1.6']
# ['2010-08-18', '23.4', '4.2', '2.1']
# ['2010-08-19', '24.3', '4', '1.9']
# ['2010-08-20', '25.4', '5', '3.2']
# ['2010-08-21', '27.8', '7.6', '4.2']
# ['2010-08-22', '28.3', '5.9', '2.5']
# ['2010-08-23', '28.9', '9.3', '6.2']
# ['2010-08-24', '27.5', '8.3', '3']
# ['2010-08-25', '24.7', '6.8', '1.9']
# ...

# %%
import csv      
 
f = open('weather.csv')  # CSV 파일을 열어서 f에 저장한다. 
data = csv.reader(f)             # reader() 함수를 이용하여 읽는다. 
header = next(data)              # 헤더를 제거한다. 
for row in data:                 # 반복 루프를 사용하여 데이터를 읽는다. 
      print(row) 
f.close()                        # 파일을 닫는다.
# Out:
# ['2010-08-01', '28.7', '8.3', '3.4']
# ['2010-08-02', '25.2', '8.7', '3.8']
# ['2010-08-03', '22.1', '6.3', '2.9']
# ['2010-08-04', '25.3', '6.6', '4.2']
# ['2010-08-05', '27.2', '9.1', '5.6']
# ['2010-08-06', '26.8', '9.8', '8']
# ['2010-08-07', '27.5', '9.1', '5']
# ['2010-08-08', '26.6', '5.9', '4']
# ['2010-08-09', '26.9', '5.1', '3.1']
# ['2010-08-10', '25.6', '10.2', '5.5']
# ['2010-08-11', '24.6', '9.4', '4.8']
# ['2010-08-12', '23.7', '8.7', '2.6']
# ['2010-08-13', '24.3', '10.9', '4.6']
# ['2010-08-14', '25', '10.8', '4.4']
# ['2010-08-15', '24.5', '16.9', '10.3']
# ['2010-08-16', '26.2', '9.8', '3.2']
# ['2010-08-17', '23.9', '4.2', '1.6']
# ['2010-08-18', '23.4', '4.2', '2.1']
# ['2010-08-19', '24.3', '4', '1.9']
# ['2010-08-20', '25.4', '5', '3.2']
# ['2010-08-21', '27.8', '7.6', '4.2']
# ['2010-08-22', '28.3', '5.9', '2.5']
# ['2010-08-23', '28.9', '9.3', '6.2']
# ['2010-08-24', '27.5', '8.3', '3']
# ['2010-08-25', '24.7', '6.8', '1.9']
# ...

# %% [markdown]
# ### 12.5 CSV에서 원하는 데이터 뽑아 보기

# %%
f = open('weather.csv')
data = csv.reader(f)
header = next(data)               # 헤더를 제거한다. 
for row in data:                  # 반복 루프를 사용하여 데이터를 읽는다. 
      print(row[3], end=',')      # 평균 풍속만 출력하고, 쉼표로 연결한다.
f.close()                         # 파일을 닫는다.
# Out:
# 3.4,3.8,2.9,4.2,5.6,8,5,4,3.1,5.5,4.8,2.6,4.6,4.4,10.3,3.2,1.6,2.1,1.9,3.2,4.2,2.5,6.2,3,1.9,2.5,1.6,2.3,4.9,6.2,4.2,2.6,5.3,1.7,3.2,3.3,4.3,7.6,6.6,2.5,7.2,3.8,1.8,3.9,1.6,2.2,1.2,2.2,3,3.5,2.8,3.6,7.9,5.8,4.1,6.1,1.8,2.8,5.6,2.1,2.2,3.3,3.2,5.9,5,5.1,3.1,3.4,3.7,2.7,2.6,3.1,2.5,5,3.2,2.9,4.5,2.9,2.9,2.1,3.9,6.3,3.9,2,3,6.1,7.1,4,3.5,5.8,6.6,7.2,5.6,3.5,3.2,2.9,3.2,3.3,2.5,7.5,3.1,2.2,2.8,6.7,3.5,5,4.1,1.9,3.9,2.7,5.1,2.2,4.3,8.8,5.2,1.8,3.9,3.9,6.5,4.2,3.7,5.8,5.1,4.2,5.7,3.7,5.4,5.6,6.4,3.4,5.9,5.4,5.4,1.8,3.6,5.1,2.4,2.1,4.3,2.3,7.6,2.9,2,5.2,3.3,3.7,5.3,6.1,4,4.6,2.5,4.3,7.8,11.1,6,6.5,3.1,4.1,5.9,2.4,3.3,5.4,2.6,2.4,3.2,2.3,3.1,5.6,5.6,3.6,3,2.9,2.5,2,2,3.2,4.6,4,3.8,2.8,1.7,3.2,1.9,3.3,2,2.5,2.4,3.5,2.4,4.6,3.5,4.2,5.2,5,5.7,9.7,4.2,7,4.5,4.3,4.4,5.6,5.4,6.3,4.8,2,4.1,6.2,5.9,2.4,5.3,7.4,3.2,4.9,2.8,2.5,5.2,2.9,3.6,2.9,4.2,4,2.9,5.5,4.4,7.1,3.8,4.8,4.1,6.6,6.2,3.8,3.4,5.8,2.9,3.2,5.3,2.7,3.7,2.1,2.7,3.9,3.4,5,5.9,3.3,3,4.2,6.1,8.3,5.4,5.9,7.4,3.3,7,5.3,4,8.8,7,1.9,7,12.1,5,2.5
# ...

# %%
f = open('weather.csv')
data = csv.reader(f)
header = next(data)               # 헤더를 제거한다. 

max_wind = 0.0
for row in data:                    # 반복 루프를 사용하여 데이터를 읽는다.
    if row[3] == '' :             # 평균 풍속 데이터가 없는 경우 0을 처리
        wind = 0
    else :
        wind = float(row[3])    # 평균 풍속 데이터를 실수로 변환해 저장
    if max_wind < wind :          # 최대 풍속을 갱신하는지 검사
        max_wind = wind         # 현재까지의 최대 풍속보다 크면 새로 기록

print('지난 10년간 울릉도의 평균 풍속중에서 최댓값은 ', max_wind, 'm/s')
# Out:
# 지난 10년간 울릉도의 평균 풍속중에서 최댓값은  14.9 m/s

# %%
f = open('weather.csv')
data = csv.reader(f)
header = next(data)               # 헤더를 제거한다. 

max_wind = 0.0
for row in data:                    # 반복 루프를 사용하여 데이터를 읽는다.
    if row[2] == '' :             # 평균 풍속 데이터가 없는 경우 0을 처리
        wind = 0
    else :
        wind = float(row[2])    # 평균 풍속 데이터를 실수로 변환해 저장
    if max_wind < wind :          # 최대 풍속을 갱신하는지 검사
        max_wind = wind         # 현재까지의 최대 풍속보다 크면 새로 기록

print('지난 10년간 울릉도의 최대 풍속은 ', max_wind, 'm/s')
# Out:
# 지난 10년간 울릉도의 최대 풍속은  26.0 m/s

# %%
f = open('weather.csv')
data = csv.reader(f)
header = next(data)               # 헤더를 제거한다. 

min_wind = 999999
for row in data:                    # 반복 루프를 사용하여 데이터를 읽는다.
    if row[3] != '':
        wind = float(row[3])    # 평균 풍속 데이터를 실수로 변환해 저장
    if min_wind > wind :         
        min_wind = wind         

print('지난 10년간 울릉도의 평균 풍속중에서 최솟값은 ', min_wind, 'm/s')
# Out:
# 지난 10년간 울릉도의 평균 풍속중에서 최솟값은  0.2 m/s

# %%
f = open('weather.csv')
data = csv.reader(f)
header = next(data)               # 헤더를 제거한다. 

max_wind = 0.0
for row in data:                    # 반복 루프를 사용하여 데이터를 읽는다.
    if row[3] != '':
        wind = float(row[3])    # 평균 풍속 데이터를 실수로 변환해 저장
    if max_wind < wind :          # 최대 풍속을 갱신하는지 검사
        max_wind = wind         # 현재까지의 최대 풍속보다 크면 새로 기록

print('지난 10년간 울릉도의 평균 풍속중에서 최댓값은 ', max_wind, 'm/s')
# Out:
# 지난 10년간 울릉도의 평균 풍속중에서 최댓값은  14.9 m/s

# %%
f = open('weather.csv')
data = csv.reader(f)
header = next(data)               # 헤더를 제거한다. 

max_wind = 0.0
min_wind = 100.0
for row in data:                    # 반복 루프를 사용하여 데이터를 읽는다.
    if row[3] != '':
        wind = float(row[3])    # 평균 풍속 데이터를 실수로 변환해 저장
    if max_wind < wind :          # 최대 풍속을 갱신하는지 검사
        max_wind = wind         # 현재까지의 최대 풍속보다 크면 새로 기록
    if min_wind > wind:
        min_wind = wind

print('지난 10년간 울릉도의 평균 풍속중에서 최댓값은 ', max_wind, 'm/s')
print('지난 10년간 울릉도의 평균 풍속중에서 최솟값은 ', min_wind, 'm/s')
# Out:
# 지난 10년간 울릉도의 평균 풍속중에서 최댓값은  14.9 m/s
# 지난 10년간 울릉도의 평균 풍속중에서 최솟값은  0.2 m/s

# %%
f = open('weather.csv')
data = csv.reader(f)
header = next(data)               # 헤더를 제거한다. 

max_wind = 0.0
min_wind = 100.0
for row in data:                    # 반복 루프를 사용하여 데이터를 읽는다.
    if row[3] != '':
        wind = float(row[3])    # 평균 풍속 데이터를 실수로 변환해 저장
    if max_wind < wind :          # 최대 풍속을 갱신하는지 검사
        max_wind = wind         # 현재까지의 최대 풍속보다 크면 새로 기록
        max_date = row[0]
    if min_wind > wind:
        min_wind = wind
        min_date = row[0]

print('지난 10년간 울릉도의 평균 풍속중에서 최댓값은 ', max_wind, 'm/s', ', 일시는 ', max_date)
print('지난 10년간 울릉도의 평균 풍속중에서 최솟값은 ', min_wind, 'm/s', ', 일시는 ', min_date)
# Out:
# 지난 10년간 울릉도의 평균 풍속중에서 최댓값은  14.9 m/s , 일시는  2015-08-25
# 지난 10년간 울릉도의 평균 풍속중에서 최솟값은  0.2 m/s , 일시는  2013-06-03

# %%
f = open('weather.csv')
data = csv.reader(f)
header = next(data)               # 헤더를 제거한다. 

max_wind = 0.0
min_wind = 100.0
for row in data:                    # 반복 루프를 사용하여 데이터를 읽는다.
    if row[3] != '':
        wind = float(row[3])    # 평균 풍속 데이터를 실수로 변환해 저장
    if max_wind < wind :          # 최대 풍속을 갱신하는지 검사
        max_wind = wind         # 현재까지의 최대 풍속보다 크면 새로 기록
        max_date = row[0]
        max_temp = row[1]
    if min_wind > wind:
        min_wind = wind
        min_date = row[0]
        min_temp = row[1]

print(f'지난 10년간 울릉도의 평균 풍속중에서 최댓값은 {max_wind}m/s, 일시는 {max_date}, 온도는 {max_temp}')
print(f'지난 10년간 울릉도의 평균 풍속중에서 최솟값은 {min_wind}m/s, 일시는 {min_date}, 온도는 {min_temp}')
# Out:
# 지난 10년간 울릉도의 평균 풍속중에서 최댓값은 14.9m/s, 일시는 2015-08-25, 온도는 20.1
# 지난 10년간 울릉도의 평균 풍속중에서 최솟값은 0.2m/s, 일시는 2013-06-03, 온도는 16.2

# %%
f = open('weather.csv')
data = csv.reader(f)
header = next(data)               

max_temp = 0.0
min_temp = 100.0
for row in data:                    
    if row[1] != '':
        temp = float(row[1]) 
    if max_temp < temp :   
        max_temp = temp       
        max_date = row[0]
    if min_temp > temp:
        min_temp = temp
        min_date = row[0]

print(f'지난 10년간 울릉도의 평균 온도 중에서 최댓값은 {max_temp}도, 일시는 {max_date}')
print(f'지난 10년간 울릉도의 평균 온도 중에서 최솟값은 {min_temp}도, 일시는 {min_date}')
# Out:
# 지난 10년간 울릉도의 평균 온도 중에서 최댓값은 31.3도, 일시는 2013-08-08
# 지난 10년간 울릉도의 평균 온도 중에서 최솟값은 -9.0도, 일시는 2018-01-24

# %%
date = '2022-05-25'
print(date.split("-")[0])
print(date.split("-")[1])
print(date.split("-")[2])
# Out:
# 2022
# 05
# 25

# %%
import matplotlib.pyplot as plt

f = open('weather.csv')
data = csv.reader(f)
header = next(data)
jan = []

for row in data:
    if row[1] != '':
        if row[0].split('-')[1] == '01':
            jan.append(float(row[1]))

plt.plot(jan, 'red')
plt.show()

# %%
f = open('weather.csv')
data = csv.reader(f)
header = next(data)
aug = []

for row in data:
    if row[1] != '':
        if row[0].split('-')[1] == '08':
            aug.append(float(row[1]))

plt.plot(aug, 'blue')
plt.show()

# %%
f = open('weather.csv')
data = csv.reader(f)
header = next(data)
jan = []
aug = []

for row in data:
    if row[1] != '':
        if row[0].split('-')[1] == '01':
            jan.append(float(row[1]))
        if row[0].split('-')[1] == '08':
            aug.append(float(row[1]))

plt.style.use('ggplot')

plt.rc('font', family='Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False # 마이너스 기호 꺠짐 방지
plt.plot(jan, 'red', label='jan')
plt.plot(aug, 'blue', label='aug')
plt.title('울릉도 1월과 8월 평균 기온 변화 그래프')
plt.xlabel('2010년도부터 이후 년도')
plt.ylabel('기온 변화')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = list(range(1, 9))
y = [0, 2, 1, 3, 7, 10, 11, 19]
p = np.polyfit(x, y, 3)
f = np.polyval(p, x)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Linear Regression Curve using 3th-polynomials')
plt.plot(x, y, 'o', x, f, '-')
plt.show()
print(p)
# Out:
# [ 0.03282828 -0.06818182  0.8037518  -0.57142857]

# %%
f = open('weather.csv')
data = csv.reader(f)
header = next(data)
aug = []

for row in data:
    if row[1] != '':
        if row[0].split('-')[1] == '08':
            aug.append(float(row[1]))

plt.style.use('seaborn-bright')
x = np.arange(0, len(aug))
p = np.polyfit(x, aug, 7)
y1 = np.polyval(p, x)
plt.plot(x, y1, '-', lw=3, label='curve fitting')
plt.plot(x, aug, 'r', label='aug')
plt.xlabel("2010년도부터 이후 년도")
plt.ylabel("기온 변화")
plt.legend()
plt.show()

# %%
f = open('weather.csv')
data = csv.reader(f)
header = next(data)
jan = []
aug = []
for row in data:
    if row[1] != '':
        if row[0].split('-')[1] == '01':
            jan.append(float(row[1]))
        if row[0].split('-')[1] == '08':
            aug.append(float(row[1]))
    
plt.style.use('seaborn-bright')
x = np.arange(0, len(jan))
p = np.polyfit(x, jan, 7)
y1 = np.polyval(p, x)
plt.plot(x, y1, '-', lw=3, label='curve fitting')
plt.plot(x, jan, 'r', label='jan')

x2 = np.arange(0, len(aug))
p2 = np.polyfit(x2, aug, 7)
y2 = np.polyval(p2, x2)
plt.plot(x2, y2, '-', lw=3, label='curve fitting')
plt.plot(x2, aug, 'b', label='aug')


plt.xlabel("2010년도부터 이후 년도")
plt.ylabel("기온 변화")
plt.legend()
plt.show()

# %%
f = open('weather.csv')
data = csv.reader(f)
header = next(data)
temp1 = []
temp2 = []

for row in data:
    if row[1] != '':
        date = row[0].split('-')
        if date[1] == '02' and date[2] == '14':
            temp1.append(float(row[1]))
        if date[1] == '05' and date[2] == '18':
            temp2.append(float(row[1]))

plt.style.use('ggplot')

plt.rc('font', family='Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False # 마이너스 기호 꺠짐 방지
plt.plot(temp1, 'red', label='2월 14일')
plt.plot(temp2, 'blue', label='5월 18일')
plt.title('평균 기온 변화 그래프')
plt.xlabel('2010년도부터 이후 년도')
plt.ylabel('기온 변화')
plt.legend()
plt.show()

# %% [markdown]
# ### LAB 12-1 울릉도는 몇 월에 바람이 가장 강할까?

# %%
# 로컬 PC에서 코드 실행하기

import csv
import matplotlib.pyplot as plt 
 
f = open('weather.csv')            # CSV 파일 열어 f에 저장 
data = csv.reader(f)                       # reader() 함수로 읽기
header = next(data)                        # 헤더를 제거

monthly_wind = [ 0 for x in range(12) ]    # 매달 풍속을 담을 리스트
days_counted = [ 0 for x in range(12) ]    # 각 달마다 측정된 일수

for row in data: 
    month = int(row[0][5:7])               # 0번 열에서 달 정보 추출
    if row[3] !=  '' :                     # 풍속 데이터 존재하는지 확인
        wind = float(row[3])               # 풍속을 얻어 온다.
        monthly_wind[month-1] += wind      # 해당 달에 풍속 데이터 추가
        days_counted[month-1] += 1         # 해당 달의 일수를 증가

for i in range(12) :
      monthly_wind[i] /= days_counted[i]   # 일수로 나누어 월평균 구하기
      
plt.plot(monthly_wind, 'blue') 
plt.show()

f.close()                                  # 파일을 닫는다.

# %%
# 코랩에서 실행하는 방법

import csv
import matplotlib.pyplot as plt 

url = 'https://raw.githubusercontent.com/dongupak/DataSciPy/master/data/csv/weather.csv'
response = urllib.request.urlopen(url)
lines = [l.decode('cp949') for l in response.readlines()]
data = csv.reader(lines)
header = next(data)               # 헤더를 제거한다. 

monthly_wind = [ 0 for x in range(12) ]    # 매달 풍속을 담을 리스트
days_counted = [ 0 for x in range(12) ]    # 각 달마다 측정된 일수

for row in data: 
    month = int(row[0][5:7])               # 0번 열에서 달 정보 추출
    if row[3] !=  '' :                     # 풍속 데이터 존재하는지 확인
        wind = float(row[3])               # 풍속을 얻어 온다.
        monthly_wind[month-1] += wind      # 해당 달에 풍속 데이터 추가
        days_counted[month-1] += 1         # 해당 달의 일수를 증가

for i in range(12) :
      monthly_wind[i] /= days_counted[i]   # 일수로 나누어 월평균 구하기
      
plt.plot(monthly_wind, 'blue') 
plt.show()

# %% [markdown]
# ### 12.7 판다스로 데이터 파일을 읽기

# %%
# 로컬 컴퓨터의 csv 파일 읽기 코드 - 코랩에서는 오류 발생
import pandas as pd
df = pd.read_csv('d:/data/countries.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-2fe8228ccc1e> in <module>()
#       1 # 로컬 컴퓨터의 csv 파일 읽기 코드 - 코랩에서는 오류 발생
#       2 import pandas as pd
# ----> 3 df = pd.read_csv('d:/data/countries.csv')
#
# ...

# %%
# 판다스를 통해서 countries 데이터 읽기
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/dongupak/DataSciPy/master/data/csv/countries.csv')

df
# Out:
#   Unnamed: 0 country      area     capital  population
# 0         KR   Korea     98480       Seoul    51780579
# 1         US     USA   9629091  Washington   331002825
# 2         JP   Japan    377835       Tokyo   125960000
# 3         CN   China   9596960     Beijing  1439323688
# 4         RU  Russia  17100000      Moscow   146748600

# %% [markdown]
# ### 12.8 인덱스와 컬럼스 객체

# %%
import pandas as pd 

df = pd.read_csv('c:/data/countries.csv', index_col = 0)
print(df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-2ed8b27f01e5> in <module>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv('c:/data/countries.csv', index_col = 0)
#       4 print(df)
#
# ...

# %% [markdown]
# ### 12.9 열을 기준으로 데이터 선택하기

# %%
import pandas as pd 

df_my_index = pd.read_csv('c:/data/countries.csv', index_col = 0)
df_no_index = pd.read_csv('c:/data/countries.csv')
print(df_my_index['population'])
print(df_no_index['population'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-5bf5500a6fec> in <module>()
#       1 import pandas as pd
#       2
# ----> 3 df_my_index = pd.read_csv('c:/data/countries.csv', index_col = 0)
#       4 df_no_index = pd.read_csv('c:/data/countries.csv')
#       5 print(df_my_index['population'])
#
# ...

# %%
import pandas as pd 

df_my_index = pd.read_csv('c:/data/countries.csv', index_col = 0)
print(df_my_index[ ['area', 'population'] ])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-93785c2be127> in <module>()
#       1 import pandas as pd
#       2
# ----> 3 df_my_index = pd.read_csv('c:/data/countries.csv', index_col = 0)
#       4 print(df_my_index[ ['area', 'population'] ])
#
# ...

# %% [markdown]
# ### 12.10 데이터 가시화하기

# %%
import pandas as pd
import matplotlib.pyplot as plt 

countries_df = pd.read_csv('c:/data/countries.csv', index_col = 0)

countries_df['population'].plot(kind='bar')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-5b662a8399f2> in <module>()
#       2 import matplotlib.pyplot as plt
#       3
# ----> 4 countries_df = pd.read_csv('c:/data/countries.csv', index_col = 0)
#       5
#       6 countries_df['population'].plot(kind='bar')
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt 

weather_df = pd.read_csv('c:/data/weather.csv', index_col = 0, encoding='CP949')
weather_df['평균풍속'].plot(kind='hist', bins=33)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-52bede5d5091> in <module>()
#       2 import matplotlib.pyplot as plt
#       3
# ----> 4 weather_df = pd.read_csv('c:/data/weather.csv', index_col = 0, encoding='CP949')
#       5 weather_df['평균풍속'].plot(kind='hist', bins=33)
#       6 plt.show()
#
# ...

# %% [markdown]
# ### 12.10 행 선택하기

# %%
countries_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-f94477fdf131> in <module>()
# ----> 1 countries_df.head()
#
# NameError: name 'countries_df' is not defined

# %%
countries_df[:3]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-4c9c308b7af1> in <module>()
# ----> 1 countries_df[:3]
#
# NameError: name 'countries_df' is not defined

# %%
countries_df.loc['KR']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-4776bf8f4fdd> in <module>()
# ----> 1 countries_df.loc['KR']
#
# NameError: name 'countries_df' is not defined

# %%
countries_df['population'][:3]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-ec68a206f4c4> in <module>()
# ----> 1 countries_df['population'][:3]
#
# NameError: name 'countries_df' is not defined

# %%
countries_df.loc['US', 'capital']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-9d323574d4e1> in <module>()
# ----> 1 countries_df.loc['US', 'capital']
#
# NameError: name 'countries_df' is not defined

# %%
countries_df['capital'].loc['US']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-e2d418a865bf> in <module>()
# ----> 1 countries_df['capital'].loc['US']
#
# NameError: name 'countries_df' is not defined

# %% [markdown]
# ### 12.12 새로운 열 생성하기

# %%
import pandas as pd
import matplotlib.pyplot as plt 

countries_df = pd.read_csv('d:/data/csv/countries.csv', index_col = 0)
countries_df['density'] = countries_df['population'] / countries_df['area']
print(countries_df)
# Out:
#    country      area     capital  population     density
# KR   Korea     98480       Seoul    51780579  525.797918
# US     USA   9629091  Washington   331002825   34.375293
# JP   Japan    377835       Tokyo   125960000  333.373033
# CN   China   9596960     Beijing  1439323688  149.977044
# RU  Russia  17100000      Moscow   146748600    8.581789

# %% [markdown]
# ### 12.11 간단히 데이터 분석하기

# %%
import pandas as pd
df_weather = pd.read_csv('https://raw.githubusercontent.com/dongupak/DataSciPy/master/data/csv/weather.csv', 
                         index_col = 0, encoding='CP949')

df_weather.describe()
# Out:
#               평균기온         최대풍속         평균풍속
# count  3653.000000  3649.000000  3647.000000
# mean     12.942102     7.911099     3.936441
# std       8.538507     3.029862     1.888473
# min      -9.000000     2.000000     0.200000
# 25%       5.400000     5.700000     2.500000
# 50%      13.800000     7.600000     3.600000
# 75%      20.100000     9.700000     5.000000
# max      31.300000    26.000000    14.900000

# %%
df_weather.head()
# Out:
#             평균기온  최대풍속  평균풍속
# 일시
# 2010-08-01  28.7   8.3   3.4
# 2010-08-02  25.2   8.7   3.8
# 2010-08-03  22.1   6.3   2.9
# 2010-08-04  25.3   6.6   4.2
# 2010-08-05  27.2   9.1   5.6

# %%
print('평균 분석 -----------------------------')
print(df_weather.mean())
print('표준편차  분석 -----------------------------')
print(df_weather.std())
# Out:
# 평균 분석 -----------------------------
# 평균기온    12.942102
# 최대풍속     7.911099
# 평균풍속     3.936441
# dtype: float64
# 표준편차  분석 -----------------------------
# 평균기온    8.538507
# 최대풍속    3.029862
# 평균풍속    1.888473
# dtype: float64

# %%
import numpy as np

pandas_std = df_weather['평균기온'].std()
numpy_std = np.std( df_weather['평균기온'] )
print(pandas_std, numpy_std)
# Out:
# 8.53850701475343 8.537338236838877

# %% [markdown]
# ### 12.21 데이터 집계 분석

# %%
df = pd.read_csv('https://raw.githubusercontent.com/dongupak/DataSciPy/master/data/csv/weather.csv', 
                 index_col = 0, encoding='CP949')
df.count()
# Out:
# 평균기온    3653
# 최대풍속    3649
# 평균풍속    3647
# dtype: int64

# %%
df['최대풍속'].count()
# Out:
# 3649

# %%
df[['최대풍속','평균풍속']].count()
# Out:
# 최대풍속    3649
# 평균풍속    3647
# dtype: int64

# %%
df[['최대풍속','평균풍속']].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-8b87b4167af6> in <module>()
# ----> 1 df[['최대풍속','평균풍속']].mean()
#
# NameError: name 'df' is not defined

# %%
df.mean()[['최대풍속', '평균풍속']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-6dc55ecd8fdd> in <module>()
# ----> 1 df.mean()[['최대풍속', '평균풍속']]
#
# NameError: name 'df' is not defined

# %% [markdown]
# ### LAB 12-2 판다스로 울릉도의 바람 세기 분석하기

# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt

weather = pd.read_csv('https://raw.githubusercontent.com/dongupak/DataSciPy/master/data/csv/weather.csv', 
                      encoding='CP949')
monthly = [ 0 for x in range(12) ]    # 달별로 구분된 12개의 데이터
monthly_wind = [ 0 for x in range(12) ]  # 각 달의 평균 풍속을 담을 리스트

weather['month'] = pd.DatetimeIndex(weather['일시']).month

weather.tail()
# Out:
#               일시  평균기온  최대풍속  평균풍속  month
# 3648  2020-07-27  22.1   4.2   1.7      7
# 3649  2020-07-28  21.9   4.5   1.6      7
# 3650  2020-07-29  21.6   3.2   1.0      7
# 3651  2020-07-30  22.9   9.7   2.4      7
# 3652  2020-07-31  25.7   4.8   2.5      7

# %%
monthly[0] = weather[ weather['month'] == 1 ] # 달별로 분리
monthly[0].mean()["평균풍속"]
# Out:
# 3.7574193548387074

# %%
monthly[1] = weather[ weather['month'] == 2 ] # 달별로 분리
monthly[1].mean()['평균풍속']
# Out:
# 3.946785714285715

# %%
monthly[2] = weather[ weather['month'] == 3 ] # 달별로 분리
monthly[2].mean()['평균풍속']
# Out:
# 4.390291262135921

# %%
# 마지막에 해당 행의 데이터가 측정된 달을 기록한 열을 추가
weather['month'] = pd.DatetimeIndex(weather['일시']).month

for i in range(12) :
    monthly[i] = weather[ weather['month'] == i+1 ] # 달별로 분리
    monthly_wind[i] = monthly[i].mean()['평균풍속']  # 개별 데이터 분석
    
plt.plot(monthly_wind, 'red')
plt.show()

# %%
monthly
# Out:
# [              일시  평균기온  최대풍속  평균풍속  month
#  153   2011-01-01   0.8  19.0  11.1      1
#  154   2011-01-02   0.1   8.5   6.0      1
#  155   2011-01-03  -0.3  10.2   6.5      1
#  156   2011-01-04   1.7   6.8   3.1      1
#  157   2011-01-05   1.2   6.9   4.1      1
#  ...          ...   ...   ...   ...    ...
#  3466  2020-01-27   5.4  15.3   7.6      1
#  3467  2020-01-28   5.7  14.9  11.6      1
#  3468  2020-01-29   4.1   9.0   6.6      1
#  3469  2020-01-30   1.8  10.2   7.7      1
#  3470  2020-01-31   1.9  10.2   5.3      1
#
#  [310 rows x 5 columns],               일시  평균기온  최대풍속  평균풍속  month
#  184   2011-02-01   3.1   4.9   2.0      2
#  185   2011-02-02   4.5   5.3   2.5      2
#  186   2011-02-03   5.4   4.5   2.4      2
#  187   2011-02-04   5.3   9.1   3.5      2
#  188   2011-02-05   3.8   6.5   2.4      2
#  ...          ...   ...   ...   ...    ...
#  3495  2020-02-25   6.6  12.2   6.5      2
#  3496  2020-02-26   3.6  10.8   7.2      2
# ...

# %% [markdown]
# ### 12.22 데이터 그룹핑

# %%
weather = pd.read_csv('https://raw.githubusercontent.com/dongupak/DataSciPy/master/data/csv/weather.csv', 
                      encoding='CP949')
weather['month'] = pd.DatetimeIndex(weather['일시']).month
means = weather.groupby('month').mean()

means
# Out:
#             평균기온      최대풍속      평균풍속
# month
# 1       1.598387  8.158065  3.757419
# 2       2.136396  8.225357  3.946786
# 3       6.250323  8.871935  4.390291
# 4      11.064667  9.305017  4.622483
# 5      16.564194  8.548710  4.219355
# 6      19.616667  6.945667  3.461000
# 7      23.328387  7.322581  3.877419
# 8      24.748710  6.853226  3.596129
# 9      20.323667  6.896333  3.661667
# 10     15.383871  7.766774  3.961613
# 11      9.889667  8.013333  3.930667
# 12      3.753548  8.045484  3.817097

# %%
sum_data = weather.groupby('month').sum()
print(sum_data)
# Out:
#          평균기온    최대풍속    평균풍속
# month
# 1       495.5  2529.0  1164.8
# 2       604.6  2303.1  1105.1
# 3      1937.6  2750.3  1356.6
# 4      3319.4  2782.2  1377.5
# 5      5134.9  2650.1  1308.0
# 6      5885.0  2083.7  1038.3
# 7      7231.8  2270.0  1202.0
# 8      7672.1  2124.5  1114.8
# 9      6097.1  2068.9  1098.5
# 10     4769.0  2407.7  1228.1
# 11     2966.9  2404.0  1179.2
# 12     1163.6  2494.1  1183.3

# %% [markdown]
# ### LAB 12-2 울릉도는 몇 월에 바람이 가장 강할까? - groupby 사용하기

# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt

weather = pd.read_csv('https://raw.githubusercontent.com/dongupak/DataSciPy/master/data/csv/weather.csv', 
                      encoding='CP949')

weather['month'] = pd.DatetimeIndex(weather['일시']).month
means = weather.groupby('month').mean()
means['평균풍속'].plot()

plt.show()

# %% [markdown]
# ### 12.13 필터링

# %%
weather['최대풍속'] >= 10.0
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3648    False
# 3649    False
# 3650    False
# 3651    False
# 3652    False
# Name: 최대풍속, Length: 3653, dtype: bool

# %%
weather[ weather['최대풍속'] >= 10.0 ]
# Out:
#               일시  평균기온  최대풍속  평균풍속  month
# 9     2010-08-10  25.6  10.2   5.5      8
# 12    2010-08-13  24.3  10.9   4.6      8
# 13    2010-08-14  25.0  10.8   4.4      8
# 14    2010-08-15  24.5  16.9  10.3      8
# 29    2010-08-30  26.2  10.5   6.2      8
# ...          ...   ...   ...   ...    ...
# 3622  2020-07-01  16.8  19.7   8.7      7
# 3632  2020-07-11  20.1  10.3   4.1      7
# 3634  2020-07-13  17.8  10.3   4.6      7
# 3635  2020-07-14  17.8  12.7   9.4      7
# 3641  2020-07-20  23.0  11.2   7.3      7
#
# [830 rows x 5 columns]

# %% [markdown]
# ### 12.14 결손값 찾아 삭제하기

# %%
weather[ weather['평균풍속'].isna() == True ]
# Out:
#               일시  평균기온  최대풍속  평균풍속  month
# 559   2012-02-11  -0.7   NaN   NaN      2
# 560   2012-02-12   0.4   NaN   NaN      2
# 561   2012-02-13   4.0   NaN   NaN      2
# 1694  2015-03-22  10.1  11.6   NaN      3
# 1704  2015-04-01   7.3  12.1   NaN      4
# 3182  2019-04-18  15.7  11.7   NaN      4

# %%
import pandas as pd

weather = pd.read_csv('https://raw.githubusercontent.com/dongupak/DataSciPy/master/data/csv/weather.csv', 
                      encoding='CP949')
missing_data = weather [ weather['평균풍속'].isna() ] 
missing_data
# Out:
#               일시  평균기온  최대풍속  평균풍속
# 559   2012-02-11  -0.7   NaN   NaN
# 560   2012-02-12   0.4   NaN   NaN
# 561   2012-02-13   4.0   NaN   NaN
# 1694  2015-03-22  10.1  11.6   NaN
# 1704  2015-04-01   7.3  12.1   NaN
# 3182  2019-04-18  15.7  11.7   NaN

# %%
weather.dropna(axis=0, how="any", inplace=True)

# %%
weather[ weather['일시'] =='2012-02-12']
# Out:
# Empty DataFrame
# Columns: [일시, 평균기온, 최대풍속, 평균풍속]
# Index: []

# %% [markdown]
# ### 12.15 결손값 보정하기

# %%
import pandas as pd

weather = pd.read_csv('https://raw.githubusercontent.com/dongupak/DataSciPy/master/data/csv/weather.csv', 
                      encoding='CP949')

weather.fillna(0, inplace = True)
weather[ weather['평균풍속'] ==0.0]
# Out:
#               일시  평균기온  최대풍속  평균풍속
# 559   2012-02-11  -0.7   0.0   0.0
# 560   2012-02-12   0.4   0.0   0.0
# 561   2012-02-13   4.0   0.0   0.0
# 1694  2015-03-22  10.1  11.6   0.0
# 1704  2015-04-01   7.3  12.1   0.0
# 3182  2019-04-18  15.7  11.7   0.0

# %%
weather = pd.read_csv('https://raw.githubusercontent.com/dongupak/DataSciPy/master/data/csv/weather.csv', 
                      encoding='CP949')

new_weather = weather.fillna(0)
weather[ weather['일시'] == '2012-02-11']
new_weather[ new_weather['일시'] == '2012-02-11']
# Out:
#              일시  평균기온  최대풍속  평균풍속
# 559  2012-02-11  -0.7   0.0   0.0

# %%
weather.fillna( weather['평균풍속'].mean(), inplace = True)
weather[ weather['일시'] == '2012-02-11']
# Out:
#              일시  평균기온      최대풍속      평균풍속
# 559  2012-02-11  -0.7  3.936441  3.936441

# %%
weather = pd.read_csv('https://raw.githubusercontent.com/dongupak/DataSciPy/master/data/csv/weather.csv', 
                      encoding='CP949')

weather['최대풍속'].fillna(weather['최대풍속'].mean(), inplace=True)
weather['평균풍속'].fillna(weather['평균풍속'].mean(), inplace=True)

weather[ weather['일시'] == '2012-02-11']
# Out:
#              일시  평균기온      최대풍속      평균풍속
# 559  2012-02-11  -0.7  7.911099  3.936441

# %% [markdown]
# ### 12.16 데이터 구조 변경

# %%
import pandas as pd 

df_1 = pd.DataFrame({'item' : ['ring0', 'ring0', 'ring1', 'ring1'], 
                     'type' : ['Gold', 'Silver', 'Gold', 'Bronze'], 
                     'price': [20000, 10000, 50000, 30000]})

# %%
df_1
# Out:
#     item    type  price
# 0  ring0    Gold  20000
# 1  ring0  Silver  10000
# 2  ring1    Gold  50000
# 3  ring1  Bronze  30000

# %%
df_2 = df_1.pivot(index='item', columns='type', values='price') 
print(df_2)
# Out:
# type    Bronze     Gold   Silver
# item
# ring0      NaN  20000.0  10000.0
# ring1  30000.0  50000.0      NaN

# %% [markdown]
# ### 12.17 데이터프레임 합치기 - concat

# %%
df_1 = pd.DataFrame( {'A' : ['a10', 'a11', 'a12'], 
                      'B' : ['b10', 'b11', 'b12'],
                      'C' : ['c10', 'c11', 'c12']} , index = ['가', '나',  '다'] )

df_2 = pd.DataFrame( {'B' : ['b23', 'b24', 'b25'],
                      'C' : ['c23', 'c24', 'c25'],
                      'D' : ['d23', 'd24', 'd25']} , index = ['다', '라',  '마'] )

# %%
df_1
# Out:
#      A    B    C
# 가  a10  b10  c10
# 나  a11  b11  c11
# 다  a12  b12  c12

# %%
df_2
# Out:
#      B    C    D
# 다  b23  c23  d23
# 라  b24  c24  d24
# 마  b25  c25  d25

# %%
df_3 = pd.concat( [df_1, df_2])
df_3
# Out:
#      A    B    C    D
# 가  a10  b10  c10  NaN
# 나  a11  b11  c11  NaN
# 다  a12  b12  c12  NaN
# 다  NaN  b23  c23  d23
# 라  NaN  b24  c24  d24
# 마  NaN  b25  c25  d25

# %% [markdown]
# ### LAB 12-1 다양한 방법으로 concat 적용해 보기

# %%
import pandas as pd 

df_1 = pd.DataFrame( {'A' : ['a10', 'a11', 'a12'], 
          'B' : ['b10', 'b11', 'b12'],
          'C' : ['c10', 'c11', 'c12']} , index = ['가', '나',  '다'] )

df_2 = pd.DataFrame( {'B' : ['b23', 'b24', 'b25'],
          'C' : ['c23', 'c24', 'c25'],
          'D' : ['d23', 'd24', 'd25']} , index = ['다', '라',  '마'] )

pd.concat( [df_1, df_2] , axis = 1, join = 'inner' )
# Out:
#      A    B    C    B    C    D
# 다  a12  b12  c12  b23  c23  d23

# %%
print( pd.concat( [df_1, df_2] , axis = 0, join = 'outer' ) )
print( pd.concat( [df_1, df_2] , axis = 0, join = 'inner' ) )
print( pd.concat( [df_1, df_2] , axis = 1, join = 'outer' ) )
print( pd.concat( [df_1, df_2] , axis = 1, join = 'inner' ) )
# Out:
#      A    B    C    D
# 가  a10  b10  c10  NaN
# 나  a11  b11  c11  NaN
# 다  a12  b12  c12  NaN
# 다  NaN  b23  c23  d23
# 라  NaN  b24  c24  d24
# 마  NaN  b25  c25  d25
#      B    C
# 가  b10  c10
# 나  b11  c11
# 다  b12  c12
# 다  b23  c23
# 라  b24  c24
# 마  b25  c25
#      A    B    C    B    C    D
# 가  a10  b10  c10  NaN  NaN  NaN
# 나  a11  b11  c11  NaN  NaN  NaN
# 다  a12  b12  c12  b23  c23  d23
# 라  NaN  NaN  NaN  b24  c24  d24
# 마  NaN  NaN  NaN  b25  c25  d25
#      A    B    C    B    C    D
# 다  a12  b12  c12  b23  c23  d23

# %% [markdown]
# ### 12.18 데이터베이스 join 방식의 데이터 병합 - merge

# %%
df_1
# Out:
#      A    B    C
# 가  a10  b10  c10
# 나  a11  b11  c11
# 다  a12  b12  c12

# %%
df_2
# Out:
#      B    C    D
# 다  b23  c23  d23
# 라  b24  c24  d24
# 마  b25  c25  d25

# %%
df_3 = df_1.merge(df_2, how='outer', on='B')
df_3
# Out:
#      A    B  C_x  C_y    D
# 0  a10  b10  c10  NaN  NaN
# 1  a11  b11  c11  NaN  NaN
# 2  a12  b12  c12  NaN  NaN
# 3  NaN  b23  NaN  c23  d23
# 4  NaN  b24  NaN  c24  d24
# 5  NaN  b25  NaN  c25  d25

# %%
df_3 = df_1.merge(df_2, how='outer', on='C')
df_3
# Out:
#      A  B_x    C  B_y    D
# 0  a10  b10  c10  NaN  NaN
# 1  a11  b11  c11  NaN  NaN
# 2  a12  b12  c12  NaN  NaN
# 3  NaN  NaN  c23  b23  d23
# 4  NaN  NaN  c24  b24  d24
# 5  NaN  NaN  c25  b25  d25

# %% [markdown]
# ### 12.18 인덱스를 키로 활용하여 merge 적용해 보기

# %%
df_1.merge(df_2, how ='outer', left_index = True, right_index = True )
# Out:
#      A  B_x  C_x  B_y  C_y    D
# 가  a10  b10  c10  NaN  NaN  NaN
# 나  a11  b11  c11  NaN  NaN  NaN
# 다  a12  b12  c12  b23  c23  d23
# 라  NaN  NaN  NaN  b24  c24  d24
# 마  NaN  NaN  NaN  b25  c25  d25

# %%
df_3 = df_1.merge(df_2, how='outer', left_index = True, right_index = True )
print(df_3)
# Out:
#      A  B_x  C_x  B_y  C_y    D
# 가  a10  b10  c10  NaN  NaN  NaN
# 나  a11  b11  c11  NaN  NaN  NaN
# 다  a12  b12  c12  b23  c23  d23
# 라  NaN  NaN  NaN  b24  c24  d24
# 마  NaN  NaN  NaN  b25  c25  d25

# %% [markdown]
# ### LAB 12-1 다양한 방법으로 merge 적용해 보기

# %%
import pandas as pd 

df_1 = pd.DataFrame( {'A' : ['a10', 'a11', 'a12'], 
          'B' : ['b10', 'b11', 'b12'],
          'C' : ['c10', 'c11', 'c12']} , index = ['가', '나',  '다'] )

df_2 = pd.DataFrame( {'B' : ['b23', 'b24', 'b25'],
          'C' : ['c23', 'c24', 'c25'],
          'D' : ['d23', 'd24', 'd25']} , index = ['다', '라',  '마'] )

print('left outer \n' , df_1.merge(df_2, how='left', on='B' ) )
print('right outer \n' ,df_1.merge(df_2, how='right', on='B' ) )
print('full outer \n' ,df_1.merge(df_2, how='outer', on='B' ) )
print('inner \n' ,df_1.merge(df_2, how='inner', on='B' ) )
# Out:
# left outer
#       A    B  C_x  C_y    D
# 0  a10  b10  c10  NaN  NaN
# 1  a11  b11  c11  NaN  NaN
# 2  a12  b12  c12  NaN  NaN
# right outer
#       A    B  C_x  C_y    D
# 0  NaN  b23  NaN  c23  d23
# 1  NaN  b24  NaN  c24  d24
# 2  NaN  b25  NaN  c25  d25
# full outer
#       A    B  C_x  C_y    D
# 0  a10  b10  c10  NaN  NaN
# 1  a11  b11  c11  NaN  NaN
# 2  a12  b12  c12  NaN  NaN
# 3  NaN  b23  NaN  c23  d23
# 4  NaN  b24  NaN  c24  d24
# 5  NaN  b25  NaN  c25  d25
# inner
#  Empty DataFrame
# Columns: [A, B, C_x, C_y, D]
# Index: []

# %% [markdown]
# ### 12.19 정렬

# %%
import pandas as pd
import matplotlib.pyplot as plt

countries_df = pd.read_csv('https://raw.githubusercontent.com/dongupak/DataSciPy/master/data/csv/countries.csv', 
                           index_col = 0)
sorted = countries_df.sort_values('area', ascending=False)
print(sorted)
# Out:
#    country      area     capital  population
# RU  Russia  17100000      Moscow   146748600
# US     USA   9629091  Washington   331002825
# CN   China   9596960     Beijing  1439323688
# JP   Japan    377835       Tokyo   125960000
# KR   Korea     98480       Seoul    51780579

# %%
countries_df = pd.read_csv('https://raw.githubusercontent.com/dongupak/DataSciPy/master/data/csv/countries.csv', index_col = 0)
countries_df.sort_values(['population', 'area'], inplace = True)
print(countries_df)
# Out:
#    country      area     capital  population
# KR   Korea     98480       Seoul    51780579
# JP   Japan    377835       Tokyo   125960000
# RU  Russia  17100000      Moscow   146748600
# US     USA   9629091  Washington   331002825
# CN   China   9596960     Beijing  1439323688

# %%
countries = pd.read_csv('../data/countries.csv', index_col = 0, encoding='CP949')
countries.sort_values(['population', 'area'], ascending = False, inplace = True)
print(countries)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-51-144a64e107b1> in <module>()
# ----> 1 countries = pd.read_csv('../data/countries.csv', index_col = 0, encoding='CP949')
#       2 countries.sort_values(['population', 'area'], ascending = False, inplace = True)
#       3 print(countries)
#
# ...
