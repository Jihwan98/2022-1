# %% [markdown]
# ## 생능출판사 (가칭)"데이터과학 파이썬" 코드 3장

# %% [markdown]
# 3.2 할당 연산자를 통해 변수에 값을 넣자

# %%
x = 100 + 200   # x에 100 + 200의 결과를 할당
x
# Out:
# 300

# %%
x = 20
y = 10
100 = x + y
# Out:
#   File "<ipython-input-3-64b8e7398cec>", line 3
#     100 = x + y
#                 ^
# SyntaxError: can't assign to literal

# %%
x = y = 100           # 여러 변수에 동일한 값을 할당하는 다중 할당문
x, y
# Out:
# (100, 100)

# %%
n1, n2 = 100, 200     # 여러 변수에 한꺼번에 여러 값을 할당하는 동시 할당문
n1, n2
# Out:
# (100, 200)

# %% [markdown]
# 3.3 수식과 연산자는 어떻게 쓰는 걸까

# %%
7 / 4
# Out:
# 1.75

# %%
8 / 4
# Out:
# 2.0

# %%
7 // 4
# Out:
# 1

# %% [markdown]
# 3.4 컴퓨터과학에서 아주 중요한 나머지 연산자 : %

# %%
p = int(input("분자를 입력하시오: "))
q = int(input("분모를 입력하시오: "))
print("나눗셈의 몫=", p // q)
print("나눗셈의 나머지=", p % q)
# Out:
# 분자를 입력하시오: 7
# 분모를 입력하시오: 4
# 나눗셈의 몫= 1
# 나눗셈의 나머지= 3

# %%
number = int(input("정수를 입력하시오: "))
print(number%2)
# Out:
# 정수를 입력하시오: 28
# 0

# %%
2 ** 7
# Out:
# 128

# %% [markdown]
# 3.5 거듭제곱 연산자 : **

# %%
a=1000
r=0.05
n=10
print(a*(1+r)**n)
# Out:
# 1628.894626777442

# %%
bottom = float(input('직각삼각형의 밑변의 길이를 입력하시오: '))
height = float(input('직각삼각형의 높이를 입력하시오: '))
hypotenuse = (bottom ** 2 + height ** 2 ) ** 0.5
print('빗변은', hypotenuse, '입니다')
# Out:
# 직각삼각형의 밑변의 길이를 입력하시오: 3
# 직각삼각형의 높이를 입력하시오: 4
# 빗변은 5.0 입니다

# %% [markdown]
#
# LAB3-1
# 거북이 그래픽으로 숫자를 입력받아 다각형을 그리자

# %%
for i in range(n) :   # 이 문장 다음에 들여쓴 내용을 n번 반복한다.
    t.forward(100)    # 여기에 반복하고 싶은 문장을 들여서 적는다.
    t.left(60)        # 여기에 반복하고 싶은 문장을 들여서 적는다.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-0b81f20bf2d7> in <module>()
# ----> 1 for i in range(n) :   # 이 문장 다음에 들여쓴 내용을 n번 반복한다.
#       2     t.forward(100)    # 여기에 반복하고 싶은 문장을 들여서 적는다.
#       3     t.left(60)        # 여기에 반복하고 싶은 문장을 들여서 적는다.
#
# NameError: name 'n' is not defined

# %%
import turtle
t = turtle.Turtle()
t.shape("turtle")
n = int(input("몇각형을 그리시겠어요?(3-6): "))

for i in range(n) :
    t.forward(100)
    t.left(360//n)
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-1-6b1535291da8> in <module>()
#       1 import turtle
# ----> 2 t = turtle.Turtle()
#       3 t.shape("turtle")
#       4 n = int(input("몇각형을 그리시겠어요?(3-6): "))
#       5
#
# /usr/lib/python3.6/turtle.py in __init__(self, shape, undobuffersize, visible)
#    3810                  visible=_CFG["visible"]):
#    3811         if Turtle._screen is None:
# -> 3812             Turtle._screen = Screen()
#    3813         RawTurtle.__init__(self, Turtle._screen,
#    3814                            shape=shape,
#
# /usr/lib/python3.6/turtle.py in Screen()
#    3660     else return the existing one."""
#    3661     if Turtle._screen is None:
# -> 3662         Turtle._screen = _Screen()
#    3663     return Turtle._screen
#    3664
#
# /usr/lib/python3.6/turtle.py in __init__(self)
#    3676         # preserved (perhaps by passing it as an optional parameter)
#    3677         if _Screen._root is None:
# -> 3678             _Screen._root = self._root = _Root()
#    3679             self._root.title(_Screen._title)
#    3680             self._root.ondestroy(self._destroy)
#
# /usr/lib/python3.6/turtle.py in __init__(self)
#     432     """Root class for Screen based on Tkinter."""
#     433     def __init__(self):
# --> 434         TK.Tk.__init__(self)
#     435
#     436     def setupcanvas(self, width, height, cwidth, cheight):
#
# /usr/lib/python3.6/tkinter/__init__.py in __init__(self, screenName, baseName, className, useTk, sync, use)
#    2021                 baseName = baseName + ext
#    2022         interactive = 0
# -> 2023         self.tk = _tkinter.create(screenName, baseName, className, interactive, wantobjects, useTk, sync, use)
#    2024         if useTk:
#    2025             self._loadtk()
#
# TclError: no display name and no $DISPLAY environment variable

# %% [markdown]
#
# LAB3-2
# 화씨온도를 섭씨온도로 변환하기

# %%
fahrenheit = int(input("화씨온도: "))
celsius = (fahrenheit - 32) * 5 / 9
print("섭씨온도:", celsius)

# %%
fahrenheit = float(input("화씨온도: "))
celsius = (fahrenheit - 32.0) * 5.0 / 9.0
print("섭씨온도:", celsius)

# %% [markdown]
#
# LAB3-3
# 몸무게와 키를 입력받아 BMI 계산하기

# %%
weight = float(input("몸무게를 kg 단위로 입력하시오: "))
height = float(input("키를 미터 단위로 입력하시오: "))

bmi = (weight / (height**2)) 
print("당신의 BMI=",  bmi)
# Out:
# 몸무게를 kg 단위로 입력하시오: 85.0
# 키를 미터 단위로 입력하시오: 1.83
# 당신의 BMI= 25.381468541909282

# %% [markdown]
# LAB3-4
# 자동 판매기 프로그램을 만들어 보자

# %%
money = int(input("투입한 돈: "))
price = int(input("물건값: "))

change = money-price
print("거스름돈: ", change)
coin500s = change // 500# 500으로 나누어서 몫이 500원짜리의 개수
change = change % 500# 500으로 나눈 나머지를 계산한다. 
coin100s = change // 100# 100으로 나누어서 몫이 100원짜리의 개수

print("500원 동전의 개수:", coin500s)
print("100원 동전의 개수:", coin100s)
# Out:
# 투입한 돈: 5000
# 물건값: 2600
# 거스름돈:  2400
# 500원 동전의 개수: 4
# 100원 동전의 개수: 4

# %% [markdown]
# 3.6 복합 할당 연산자라는 데이터 과학을 위한 연산자

# %%
num = 200
num += 100          # 200 + 100 연산을 수행하여 그 결과를 num에 할당
num

# %%
num -= 100          # 300 – 100 연산을 수행하여 그 결과를 num에 할당
num

# %%
num *= 20           # 200 * 20 연산을 수행하여 그 결과를 num에 할당
num

# %%
num /= 2            # 4000 / 2 연산을 수행하여 그 결과를 num에 할당
num

# %%
num /= 2            # 4000 / 2 연산을 수행하여 그 결과를 num에 할당
num

# %% [markdown]
# 3.7 두 값의 크기를 비교하는 비교 연산자

# %%
a != b

# %%
a > b

# %%
a < b

# %%
a >= b

# %%
a >= b            # 두 개의 기호로 표현된 관계 연산자는 띄어쓰면 안 된다.

# %%
a => b             # 두 개 기호로 표현된 관계 연산자의 순서를 뒤집어도 안 된다.

# %% [markdown]
# 3.8 AND, OR, NOT도 연산자로 사용가능하다 : 논리 연산자

# %%
10 > 20 # 10은 20보다 작으므로 10 > 20은 False가 됨

# %%
10 < 20# 10은 20보다 작으므로 10 < 20은 True가 됨

# %%
bool(9) # 9는 0이 아니므로 True가 됨
# Out:
# True

# %%
bool(-1) # -1 역시 0이 아니므로 True가 됨
# Out:
# True

# %%
bool(0)# 숫자 값중에서는 유일하게 0의 값만 False가 됨
# Out:
# False

# %%
bool(None)# None은 값이 없음을 표현함, 따라서 False가 됨
# Out:
# False

# %%
bool('')# 빈 문자열이므로 False가 됨
# Out:
# False

# %%
bool('hello')# 문자열 값이 있으므로 True가 됨
# Out:
# True

# %% [markdown]
# 3.9 이진수를 잘 다루는 컴퓨터에 최적화된 연산자 : 비트 연산자

# %%
bin(9)
# Out:
# '0b1001'

# %%
bin(10)
# Out:
# '0b1010'

# %%
bin(9 & 10)
# Out:
# '0b1000'

# %%
bin(9 | 10)
# Out:
# '0b1011'

# %%
bin(~9)
# Out:
# '-0b1010'

# %%
bin(9)      # 이진수 00001001
# Out:
# '0b1001'

# %%
bin(10)     # 이진수 00001010
# Out:
# '0b1010'

# %%
9 ^ 10      # 결과는 00000011 = 십진수 3
# Out:
# 3

# %%
bin(9 ^ 10) # 앞 부분의 0은 모두 사라지고 1이 나타나는 곳부터 출력된다.
# Out:
# '0b11'

# %%
4 << 1      # 00100을 한 비트 왼쪽으로 이동하여 01000을 만든다.
# Out:
# 8

# %%
4 << 2      # 00100을 두 비트 왼쪽으로 이동하여 10000을 만든다.
# Out:
# 16

# %%
num = 2     # 정수 2는 이진수 10(2)으로 표현됨
num
# Out:
# 2

# %%
num <<= 1   # 정수 2를 1비트 왼쪽 이동시키면 100(4)가 됨
num
# Out:
# 4

# %%
num <<= 1   # 정수 4를 1비트 더 왼쪽 이동시키면 1000(8)이 됨
num
# Out:
# 8

# %%
num >>= 1   # 정수 8를 1비트 오른쪽쪽 이동시키면 100(4)가 됨
num
# Out:
# 4

# %% [markdown]
#
# LAB3-5
# 평균 구하기 - 연산자 우선순위

# %%
x = int(input("첫 번째 수를 입력하시오: "))
y = int(input("두 번째 수를 입력하시오: "))
z = int(input("세 번째 수를 입력하시오: "))
 
avg = (x + y + z) / 3   # 올바르게 고쳐진 계산
print("평균 =", avg)
# Out:
# 평균 = 2.0

# %%
import random
random.random()
# Out:
# 0.6549626587140109

# %%
random.random()
# Out:
# 0.5708626915098051

# %%
random.randint(1, 7)       # 1이상 7이하(7을 포함)의 임의의 정수를 반환
# Out:
# 3

# %%
 random.randrange(1, 7)     # 1이상 7미만(7을 포함안함)의 임의의 정수를 반환
# Out:
# 6

# %%
random.randrange(0, 10, 2) # 0, 2, 4, 8 중(10은 포함 안함) 하나를 반환함
# Out:
# 4

# %%
random.randrange(0, 10, 2) # 0, 2, 4, 8 중(10은 포함 안함) 하나를 반환함
# Out:
# 6

# %%
lst = [10, 20, 30, 40, 50]
random.shuffle(lst)

# %%
lst
# Out:
# [10, 50, 20, 40, 30]

# %%
random.choice(lst)
# Out:
# 30

# %%
import math
math.pow(3, 3)    # 3의 3 제곱
# Out:
# 27.0

# %%
math.fabs(-99)    # -99의 실수 절대값
# Out:
# 99.0

# %%
math.log(2.71828)
# Out:
# 0.999999327347282

# %%
math.log(100, 10) # 로그 10을 밑으로 하는 100값
# Out:
# 2.0

# %%
math.pi           # 원주율
# Out:
# 3.141592653589793

# %%
math.sin(math.pi/2.0)   # sin() 함수의 인자로 PI/2.0를 넣어보자
# Out:
# 1.0

# %%
math.sin(math.pi)
# Out:
# 1.2246467991473532e-16

# %%
from math import *

sin(pi)
# Out:
# 1.2246467991473532e-16

# %%
cos(pi)
# Out:
# -1.0

# %%
# 심화문제
print('a     ' , 'n     ', 'a ** n')
n = 2; a = 2
print(a, '    ' , n , '    ', a ** n)
a = 3
print(a, '    ' , n , '    ', a ** n)
a = 4
print(a, '    ' , n , '    ', a ** n)
a = 5
print(a, '    ' , n , '    ', a ** n)
a = 6
print(a, '    ' , n , '    ', a ** n)
# Out:
# a      n      a ** n
# 2      2      4
# 3      2      9
# 4      2      16
# 5      2      25
# 6      2      36

# %%
# 심화문제 3.5
print(bin(5))
print(bin(6))
# Out:
# 0b101
# 0b110

# %%
# 심화문제 3.7
number = int(input("세 자리 정수를 입력하시오 : ")) 
print('백의 자리 :', number // 100)
print('십의 자리 :', number % 100 // 10)
print('일의 자리 :', number % 100 % 10)
# Out:
# 백의 자리 : 3
# 십의 자리 : 4
# 일의 자리 : 9

# %%
# 심화문제 3.10
x1 = int(input("x1 좌표를 입력하시오 : ")) 
y1 = int(input("y1 좌표를 입력하시오 : ")) 
x2 = int(input("x2 좌표를 입력하시오 : ")) 
y2 = int(input("y2 좌표를 입력하시오 : ")) 
square = (x1 - x2) ** 2 + (y1 - y2) ** 2
print('두 점의 거리:', square ** 0.5)
# Out:
# 두 점의 거리: 14.142135623730951

# %%
# 심화문제 3.11
x1 = int(input("x1 좌표를 입력하시오 : ")) 
y1 = int(input("y1 좌표를 입력하시오 : ")) 
x2 = int(input("x2 좌표를 입력하시오 : ")) 
y2 = int(input("y2 좌표를 입력하시오 : ")) 
area = (x2 - x1) * (y2 - y1) * 0.5
print('직각삼각형의 면적은 :', area)
# Out:
# 직각삼각형의 면적은 : 6.0

# %%
# 심화문제 3.12
PI = 3.14
# (1) 모서리의 길이가 13인 정육면체.
edge = 13
print('모서리의 길이가 13인 정육면체의 부피는 :', edge ** 3)
# (2) 모서리의 길이가 22인 정육면체.
edge = 22
print('모서리의 길이가 22인 정육면체의 부피는 :', edge ** 3)
# (3) 가로, 세로, 길이가 각각 17, 25,16인 직육면체.
edge1 = 17
edge2 = 25
edge3 = 16
print('가로, 세로, 길이가 각각 17, 25,16인 직육면체의 부피는 :', edge1 * edge2 * edge3)
# Out:
# 모서리의 길이가 13인 정육면체의 부피는 : 2197
# 모서리의 길이가 22인 정육면체의 부피는 : 10648
# 가로, 세로, 길이가 각각 17, 25,16인 직육면체의 부피는 : 6800

# %%
# (4) 반지름과 높이가 각각 10, 15인 원뿔.
PI = 3.14
r = 10
height = 15
print('반지름과 높이가 각각 10, 15인 원뿔의 부피는 :', PI * r ** 2 * height / 3)
# Out:
# 반지름과 높이가 각각 10, 15인 원뿔의 부피는 : 1570.0

# %%
# (5) 반지름이 25인 구.
r = 25
print('반지름이 25인 구의 부피는 :', PI * r ** 3 * 4 / 3)
# (6) 반지름과 높이가 각각 10, 15인 원기둥.
r = 10
height = 15
print('반지름과 높이가 각각 10, 15인 원기둥의 부피는 :', PI * r ** 2 * height)
# Out:
# 반지름이 25인 구의 부피는 : 65416.666666666664
# 반지름과 높이가 각각 10, 15인 원기둥의 부피는 : 4710.0
